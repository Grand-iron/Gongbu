# %%
import tensorflow as tf
import matplotlib as mlt
import seaborn as sys
import pandas as pd
import numpy as np

# %%
a=pd.read_csv('iris3.csv')

# %%
a.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
x=a.iloc[:,0:4]
y=a.iloc[:,4]
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y=pd.get_dummies(y)
y[0:5]
# Out:
#    Iris-setosa  Iris-versicolor  Iris-virginica
# 0         True            False           False
# 1         True            False           False
# 2         True            False           False
# 3         True            False           False
# 4         True            False           False

# %%
model=tf.keras.Sequential()

# %%
model.add(tf.keras.layers.Dense(12,input_dim=4,activation='relu'))
model.add(tf.keras.layers.Dense(8,  activation='relu'))
model.add(tf.keras.layers.Dense(3,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer='adam')
model.fit(x,y,epochs=30, batch_size=5)
# Out:
# Epoch 1/30
# 30/30 [==============================] - 2s 4ms/step - loss: 1.1146
# Epoch 2/30
# 30/30 [==============================] - 0s 3ms/step - loss: 1.0696
# Epoch 3/30
# 30/30 [==============================] - 0s 3ms/step - loss: 1.0477
# Epoch 4/30
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0245
# Epoch 5/30
# 30/30 [==============================] - 0s 3ms/step - loss: 0.9985
# Epoch 6/30
# 30/30 [==============================] - 0s 3ms/step - loss: 0.9712
# Epoch 7/30
# 30/30 [==============================] - 0s 3ms/step - loss: 0.9312
# Epoch 8/30
# 30/30 [==============================] - 0s 4ms/step - loss: 0.8710
# Epoch 9/30
# 30/30 [==============================] - 0s 3ms/step - loss: 0.8112
# Epoch 10/30
# 30/30 [==============================] - 0s 3ms/step - loss: 0.7585
# Epoch 11/30
# 30/30 [==============================] - 0s 3ms/step - loss: 0.7071
# Epoch 12/30
# 30/30 [==============================] - 0s 3ms/step - loss: 0.6642
# Epoch 13/30
# 30/30 [==============================] - 0s 3ms/step - loss: 0.6168
# Epoch 14/30
# 30/30 [==============================] - 0s 3ms/step - loss: 0.5641
# Epoch 15/30
# 30/30 [==============================] - 0s 3ms/step - loss: 0.5182
# Epoch 16/30
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4675
# Epoch 17/30
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4271
# Epoch 18/30
# 30/30 [==============================] - 0s 5ms/step - loss: 0.3965
# Epoch 19/30
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3573
# Epoch 20/30
# 30/30 [==============================] - 0s 4ms/step - loss: 0.3205
# Epoch 21/30
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3092
# Epoch 22/30
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2976
# Epoch 23/30
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2500
# Epoch 24/30
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2340
# Epoch 25/30
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2157
# Epoch 26/30
# 30/30 [==============================] - 0s 4ms/step - loss: 0.2010
# Epoch 27/30
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1810
# Epoch 28/30
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1736
# Epoch 29/30
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1751
# Epoch 30/30
# 30/30 [==============================] - 0s 3ms/step - loss: 0.1487
